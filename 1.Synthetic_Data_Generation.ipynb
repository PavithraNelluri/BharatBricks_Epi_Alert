# %%
import random
import pandas as pd
from datetime import datetime, timedelta

symptom_list = ['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing', 'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity', 'ulcers_on_tongue', 'muscle_wasting', 'vomiting', 'burning_micturition', 'spotting_ urination', 'fatigue', 'weight_gain', 'anxiety', 'cold_hands_and_feets', 'mood_swings', 'weight_loss', 'restlessness', 'lethargy', 'patches_in_throat', 'irregular_sugar_level', 'cough', 'high_fever', 'sunken_eyes', 'breathlessness', 'sweating', 'dehydration', 'indigestion', 'headache', 'yellowish_skin', 'dark_urine', 'nausea', 'loss_of_appetite', 'pain_behind_the_eyes', 'back_pain', 'constipation', 'abdominal_pain', 'diarrhoea', 'mild_fever', 'yellow_urine', 'yellowing_of_eyes', 'acute_liver_failure', 'fluid_overload', 'swelling_of_stomach', 'swelled_lymph_nodes', 'malaise', 'blurred_and_distorted_vision', 'phlegm', 'throat_irritation', 'redness_of_eyes', 'sinus_pressure', 'runny_nose', 'congestion', 'chest_pain', 'weakness_in_limbs', 'fast_heart_rate', 'pain_during_bowel_movements', 'pain_in_anal_region', 'bloody_stool', 'irritation_in_anus', 'neck_pain', 'dizziness', 'cramps', 'bruising', 'obesity', 'swollen_legs', 'swollen_blood_vessels', 'puffy_face_and_eyes', 'enlarged_thyroid', 'brittle_nails', 'swollen_extremeties', 'excessive_hunger', 'extra_marital_contacts', 'drying_and_tingling_lips', 'slurred_speech', 'knee_pain', 'hip_joint_pain', 'muscle_weakness', 'stiff_neck', 'swelling_joints', 'movement_stiffness', 'spinning_movements', 'loss_of_balance', 'unsteadiness', 'weakness_of_one_body_side', 'loss_of_smell', 'bladder_discomfort', 'foul_smell_of urine', 'continuous_feel_of_urine', 'passage_of_gases', 'internal_itching', 'toxic_look_(typhos)', 'depression', 'irritability', 'muscle_pain', 'altered_sensorium', 'red_spots_over_body', 'belly_pain', 'abnormal_menstruation', 'dischromic _patches', 'watering_from_eyes', 'increased_appetite', 'polyuria', 'family_history', 'mucoid_sputum', 'rusty_sputum', 'lack_of_concentration', 'visual_disturbances', 'receiving_blood_transfusion', 'receiving_unsterile_injections', 'coma', 'stomach_bleeding', 'distention_of_abdomen', 'history_of_alcohol_consumption', 'fluid_overload.1', 'blood_in_sputum', 'prominent_veins_on_calf', 'palpitations', 'painful_walking', 'pus_filled_pimples', 'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting', 'small_dents_in_nails', 'inflammatory_nails', 'blister', 'red_sore_around_nose', 'yellow_crust_ooze', 'prognosis']

pincodes = [
    522503, 522020,  # Amaravati
    791111, 791113,  # Itanagar
    781005, 781006,  # Dispur (Guwahati)
    800001, 800004,  # Patna
    492001, 492007,  # Raipur
    403001, 403002,  # Panaji
    382010, 382011,  # Gandhinagar
    160001, 160017,  # Chandigarh
    171001, 171002,  # Shimla
    834001, 834002,  # Ranchi
    560001, 560002,  # Bengaluru
    695001, 695014,  # Thiruvananthapuram
    462001, 462003,  # Bhopal
    400001, 400002,  # Mumbai
    795001, 795004,  # Imphal
    793001, 793002,  # Shillong
    796001, 796007,  # Aizawl
    797001, 797003,  # Kohima
    751001, 751002,  # Bhubaneswar
    302001, 302003,  # Jaipur
    600001, 600003,  # Chennai
    500001, 500002,  # Hyderabad
    799001, 799006,  # Agartala
    226001, 226002,  # Lucknow
    700001, 700007   # Kolkata
]

winter_boost = ["cough","runny_nose","congestion","phlegm","throat_irritation"]
monsoon_boost = ["high_fever","vomiting","joint_pain","headache"]
summer_boost = ["dehydration","diarrhoea","fatigue"]

regional_map = {
"cough":["cough","खांसी","இருமல்","దగ్గు"],
"high_fever":["high_fever","बुखार","காய்ச்சல்","జ్వరం"],
"vomiting":["vomiting","उल्टी","வாந்தி","వాంతి"],
"runny_nose":["runny_nose","नाक बहना","மூக்கு ஒழுகுதல்"],
"itching":["itching","खुजली","அரிப்பு"]
}

start_date=datetime(2023,1,1)
end_date=datetime(2024,12,31)

rows=[]
report_id=0
date=start_date

while date<=end_date:
    for pincode in pincodes:
        reports=random.randint(1,4)
        for _ in range(reports):
            report_id+=1
            month=date.month
            if month in [12,1,2]:
                seasonal=winter_boost
            elif month in [6,7,8,9]:
                seasonal=monsoon_boost
            elif month in [3,4,5]:
                seasonal=summer_boost
            else:
                seasonal=[]
            symptoms=set()

            # seasonal bias
            # Dec–Feb → winter
            # Jun–Sep → monsoon
            # Mar–May → summer
            for s in seasonal:
                if random.random()<0.5:
                    symptoms.add(s)

            # add random symptoms from full list
            while len(symptoms)<random.randint(2,5):
                symptoms.add(random.choice(symptom_list))

            final_symptoms=[]

            for s in symptoms:
                if s in regional_map:
                    final_symptoms.append(random.choice(regional_map[s]))
                else:
                    final_symptoms.append(s)
            rows.append([
                pincode,
                date.strftime("%Y-%m-%d"),
                report_id,
                ";".join(final_symptoms)
            ])

    date+=timedelta(days=1)

df=pd.DataFrame(rows,columns=[
"pincode",
"update_date",
"report_no",
"symptoms"
])

print("Rows generated:",len(df))
df.head()
# Out:
# Rows generated: 91349
#    pincode  ...                                           symptoms
# 0   522503  ...                throat_irritation;இருமல்;runny_nose
# 1   522020  ...  pain_in_anal_region;loss_of_appetite;phlegm;மூ...
# 2   791111  ...  throat_irritation;excessive_hunger;cold_hands_...
# 3   791111  ...  fluid_overload;bloody_stool;congestion;runny_nose
# 4   791113  ...        throat_irritation;खांसी;congestion;नाक बहना
#
# [5 rows x 4 columns]

# %%
spark_df = spark.createDataFrame(df)
spark_df.write.format("delta").mode("overwrite").saveAsTable("synthetic_health_data")

# %%
# %sql
SELECT * FROM synthetic_health_data LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- Number of reports per day
SELECT
  update_date,
  COUNT(*) AS num_reports
FROM
  synthetic_health_data
GROUP BY
  update_date
ORDER BY
  update_date;

-- Histogram of symptoms
SELECT
  symptom,
  COUNT(*) AS report_count
FROM (
  SELECT
    explode(split(symptoms, ';')) AS symptom
  FROM
    synthetic_health_data
) t
GROUP BY
  symptom
ORDER BY
  report_count DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
